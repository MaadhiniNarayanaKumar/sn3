# %%
pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (from requests) (2024.2.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (from beautifulsoup4) (2.5)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !apt update
# !apt install chromium-chromedriver
# !pip install selenium

from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

wd = webdriver.Chrome(options=options)
# Out:
# 'apt' is not recognized as an internal or external command,
# operable program or batch file.
# 'apt' is not recognized as an internal or external command,
# operable program or batch file.
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: selenium in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (4.18.1)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (from selenium) (2.2.1)
# Requirement already satisfied: trio~=0.17 in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (from selenium) (0.24.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (from selenium) (2024.2.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (from selenium) (4.9.0)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (from trio~=0.17->selenium) (3.6)
# Requirement already satisfied: outcome in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (from trio~=0.17->selenium) (1.16.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\maanu\setnext official\smarty\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
def topic(url):
    import requests
    from bs4 import BeautifulSoup
    html_doc = requests.get(url)
    soup = BeautifulSoup(html_doc.text,'html.parser')
    return soup

# %%
gift_for_riders_links = []
j = topic("https://www.smartpakequine.com/search/SearchByParameter?parameters=%7B%22Query%22%3A%221420%22%2C%22Type%22%3A%22category%22%2C%22Start%22%3A0%2C%22Size%22%3A200%2C%22Sort%22%3A1%2C%22Facets%22%3A%5B%5D%7D")
# print(j)
for i in j.find_all(class_='product'):
  gift_for_riders_links.append("https://www.smartpakequine.com/"+i.find('a').get('href'))
  #gift_for_riders_links



#print(gift_for_riders_links)

print(len(gift_for_riders_links))
# Out:
# ['https://www.smartpakequine.com//pt/one-k-defender-ccs-mips-helmet-22770', 'https://www.smartpakequine.com//pt/roeckl-roeckgrip-gloves-2212', 'https://www.smartpakequine.com//pt/one-k-defender-matte-helmet-11807', 'https://www.smartpakequine.com//pt/ada-thinsulate-winter-barn-boot-23492', 'https://www.smartpakequine.com//pt/charles-owen-ayr8-plus-leather-look-helmet-9716', 'https://www.smartpakequine.com//pt/charles-owen-ayr8-plus-helmet-13850', 'https://www.smartpakequine.com//pt/the-tailored-sportsman-ice-fil-long-sleeve-11636', 'https://www.smartpakequine.com//pt/charles-owen-halo-mips-helmet-23636', 'https://www.smartpakequine.com//pt/ada-thinsulate-winter-fleece-lined-chelsea-boot-by-smartpak-25755', 'https://www.smartpakequine.com//pt/trauma-void-eq3-smooth-shell-helmet-18199', 'https://www.smartpakequine.com//pt/tipperary-sportage-helmet-4850', 'https://www.smartpakequine.com//pt/piper-trainers-coat-ii-by-smartpak-25776', 'https://www.smartpakequine.com//pt/eqx-kylo-mips-helmet-by-charles-owen--25876', 'https://www.smartpakequine.com//pt/trauma-void-pardus-smooth-shell-helmet-24437', 'https://www.smartpakequine.com//pt/hadley-curvy-fit-grip-breeches-by-smartpak-knee-patch-24030', 'https://www.smartpakequine.com//pt/the-tailored-sportsman-midrise-hunterjumper-boot-sock-breech--21870', 'https://www.smartpakequine.com//pt/the-tailored-sportsman-vintage-tan-patch-mid-rise-breech-19564', 'https://www.smartpakequine.com//pt/piper-long-sleeve-show-shirt-by-smartpak-13986', 'https://www.smartpakequine.com//pt/charles-owen-myps-helmet-20864', 'https://www.smartpakequine.com//pt/piper-softshell-show-coat-ii-by-smartpak-16409', 'https://www.smartpakequine.com//pt/hadley-highrise-breeches-by-smartpak--full-seat-23066', 'https://www.smartpakequine.com//pt/tipperary-windsor-rose-gold-wide-brim-mips-helmet-22073', 'https://www.smartpakequine.com//pt/piper-midweight-tights-by-smartpak--full-seat-23432', 'https://www.smartpakequine.com//pt/hadley-highrise-breeches-by-smartpak--knee-patch-23067', 'https://www.smartpakequine.com//pt/trauma-void-lynx-smooth-helmet-20422', 'https://www.smartpakequine.com//pt/ariat-heritage-contour-ii-h2o-insulated-23553', 'https://www.smartpakequine.com//pt/one-k-avance-wide-brim-chrome-stripe-helmet-19865', 'https://www.smartpakequine.com//pt/piper-smartcore-long-sleeve--zip-sun-shirt-19332', 'https://www.smartpakequine.com//pt/hadley-midrise-breeches-by-smartpak--knee-patch-14691', 'https://www.smartpakequine.com//pt/piper-evolution-breeches-by-smartpak--knee-patch-23063', 'https://www.smartpakequine.com//pt/ada-tall-lace-up-boot-by-smartpak-18126', 'https://www.smartpakequine.com//pt/ada-chelsea-boot-by-smartpak-18125', 'https://www.smartpakequine.com//pt/piper-stretch-denim-breeches-by-smartpak-full-seat-24033', 'https://www.smartpakequine.com//pt/samshield-shadowmatt-helmet-9903', 'https://www.smartpakequine.com//pt/piper-mesh-show-coat-by-smartpak-23060', 'https://www.smartpakequine.com//pt/ariat-langdale-h20-boot-17345', 'https://www.smartpakequine.com//pt/piper-evolution-breeches-by-smartpak--full-seat-23064', 'https://www.smartpakequine.com//pt/hadley-winter-tech-softshell-breeches-by-smartpak--full-seat-25702', 'https://www.smartpakequine.com//pt/heritage-premier-show-gloves-9805', 'https://www.smartpakequine.com//pt/ada-tall-country-leather-boot-by-smartpak-20470', 'https://www.smartpakequine.com//pt/piper-evolution-highrise-breeches-by-smartpak--knee-patch-23431', 'https://www.smartpakequine.com//pt/hadley-midrise-breeches-by-smartpak--full-seat-14690', 'https://www.smartpakequine.com//pt/hadley-sunshield-long-sleeve-14-zip-by-smartpak--15903', 'https://www.smartpakequine.com//pt/trauma-void-eq3-microfiber-helmet-19558', 'https://www.smartpakequine.com//pt/piper-evolution-highrise-breeches-by-smartpak--full-seat-23429', 'https://www.smartpakequine.com//pt/effax-total-leather-care-bundle-25720', 'https://www.smartpakequine.com//pt/dublin-eskimo-winter-boot-ii-17952', 'https://www.smartpakequine. ...
# 187

# %%
gift_for_horses_links = []
j = topic("https://www.smartpakequine.com/search/SearchByParameter?parameters=%7B%22Query%22%3A%221429%22%2C%22Type%22%3A%22category%22%2C%22Start%22%3A0%2C%22Size%22%3A200%2C%22Sort%22%3A1%2C%22Facets%22%3A%5B%5D%7D")
# print(j)
for i in j.find_all(class_='product'):
  gift_for_horses_links.append("https://www.smartpakequine.com/"+i.find('a').get('href'))
  #gift_for_riders_links



# print(gift_for_horses_links)

print(len(gift_for_horses_links))
# Out:
# 196

# %%
gift_for_kids_links = []
j = topic("https://www.smartpakequine.com/search/SearchByParameter?parameters=%7B%22Query%22%3A%22437%22%2C%22Type%22%3A%22category%22%2C%22Start%22%3A0%2C%22Size%22%3A200%2C%22Sort%22%3A1%2C%22Facets%22%3A%5B%5D%7D")
# print(j)
for i in j.find_all(class_='product'):
  gift_for_kids_links.append("https://www.smartpakequine.com/"+i.find('a').get('href'))
  #gift_for_riders_links



# print(gift_for_horses_links)

print(len(gift_for_kids_links))
# Out:
# 48

# %%
gift_for_horses_trainers_links = []
j = topic("https://www.smartpakequine.com/search/SearchByParameter?parameters=%7B%22Query%22%3A%222173%22%2C%22Type%22%3A%22category%22%2C%22Start%22%3A0%2C%22Size%22%3A200%2C%22Sort%22%3A1%2C%22Facets%22%3A%5B%5D%7D")
# print(j)
for i in j.find_all(class_='product'):
  gift_for_horses_trainers_links.append("https://www.smartpakequine.com/"+i.find('a').get('href'))
  #gift_for_riders_links



# print(gift_for_horses_links)

print(len(gift_for_horses_trainers_links))
# Out:
# 39

# %%
personalised_horse_gifts_links = []
j = topic("https://www.smartpakequine.com/search/SearchByParameter?parameters=%7B%22Query%22%3A%22645%22%2C%22Type%22%3A%22category%22%2C%22Start%22%3A0%2C%22Size%22%3A200%2C%22Sort%22%3A1%2C%22Facets%22%3A%5B%5D%7D")
# print(j)
for i in j.find_all(class_='product'):
  personalised_horse_gifts_links.append("https://www.smartpakequine.com/"+i.find('a').get('href'))
  #gift_for_riders_links



# print(gift_for_horses_links)

print(len(personalised_horse_gifts_links))
# Out:
# 61

# %%
gift_cretificates = ["https://www.smartpakequine.com/pt/gift-certificate-2830"]
#only one gift card template available can be modified with amt in html only

# %%
gift_for_dogs_links = []
j = topic("https://www.smartpakequine.com/search/SearchByParameter?parameters=%7B%22Query%22%3A%221714%22%2C%22Type%22%3A%22category%22%2C%22Start%22%3A0%2C%22Size%22%3A200%2C%22Sort%22%3A1%2C%22Facets%22%3A%5B%5D%7D")
# print(j)
for i in j.find_all(class_='product'):
  gift_for_dogs_links.append("https://www.smartpakequine.com/"+i.find('a').get('href'))
  #gift_for_riders_links



# print(gift_for_horses_links)

print(len(gift_for_dogs_links))
# Out:
# 39

# %%
Treats_Toys_for_Horses_Gifts = []
j = topic("https://www.smartpakequine.com/treats-and-toys-for-horses--gifts-2026pc")
# print(j)
for i in j.find_all(class_='product'):
  Treats_Toys_for_Horses_Gifts.append("https://www.smartpakequine.com/"+i.find('a').get('href'))
  #gift_for_riders_links



# print(gift_for_horses_links)

print(len(Treats_Toys_for_Horses_Gifts))
# Out:
# 25

# %%
from bs4 import BeautifulSoup
import re
import pandas as pd
# Out:
# C:\Users\maanu\AppData\Local\Temp\ipykernel_1704\3313675712.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
product_gift=gift_for_riders_links+gift_for_horses_links+gift_for_kids_links+gift_for_horses_trainers_links+personalised_horse_gifts_links+gift_cretificates+gift_for_dogs_links+Treats_Toys_for_Horses_Gifts
print(len(product_gift))
# Out:
# 595

# %%
desc=[]
name=[]
rating=[]
image=[]
price=[]
id=[]
brand=[]
j=0
errorlist=[]
for i in gift_for_dogs_links:
    print(j)
    wd.get(i)
    html_content = wd.page_source
    soup = BeautifulSoup(html_content, 'html.parser')
    try:
      try:
            item_number = soup.find(id="productManufacturer").text
            item = re.findall(r'\d+', item_number)
            item_str = "".join(item)
            id.append(item_str)
      except:
            id.append('')
      #id
      try:
                item_number = soup.find(id="productManufacturer").find('a').text
                # item = re.findall(r'\d+', item_number)
                # item_str = "".join(item)
                brand.append(item_number)
      except:
                brand.append('')
      #brand
      try:
            des=soup.find(id="overview-section",class_="content-section").text.strip().replace("\n\n","").replace("   ","").replace("\n"," ")
      except AttributeError:
            des=""
      try:
            package_options=soup.find(class_="packagingOptions").text.strip().replace("\n\n\n\n","").replace("\n"," ").replace("/","").replace("   ","")
      except AttributeError:
            package_options=""
      try:
            det=soup.find(class_="pc-bg pc-bg-alt").text.strip().replace("\n\n\n","").replace("\n"," ").replace("   ","")
      except AttributeError:
            det=""

      joined = "".join([package_options,des,det])
      desc.append(joined)
      #desc
      try:
            name.append(soup.find(class_="pc-info-title").text.strip())
      except AttributeError:
            name.append(soup.find(class_="pageTitle").text.strip())
      #name        
      try:
            price.append(soup.find(class_="currentCost",attrs={'data-bind': 'text: costAfterAutoShip'}).text)
      except AttributeError as e:
            try:
                  price.append(soup.find(attrs={'data-bind': 'text: current'}).text)
            except AttributeError:
                  price.append(soup.find(attrs={'data-bind': 'text: cost'}).text)
      #price                
      link=soup.find(id="image-control").find("img").get("src")
      image.append("https:"+link)
      #image    
      try:
            rating.append(soup.find(itemprop="ratingValue").text)
      except AttributeError:
            rating.append('0')

      #rating  
    except:
          errorlist.append(i)

    #print(name[j])
    j=j+1
# Out:
# 0
# 1
# 2
# 3
# 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 12
#      10 for i in gift_for_dogs_links:
#      11     print(j)
# ---> 12     wd.get(i)
#      13     html_content = wd.page_source
#      14     soup = BeautifulSoup(html_content, 'html.parser')
#
# File c:\Users\maanu\setnext official\smarty\.venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:356, in WebDriver.get(self, url)
#     354 def get(self, url: str) -> None:
#     355     """Loads a web page in the current browser session."""
# --> 356     self.execute(Command.GET, {"url": url})
#
# File c:\Users\maanu\setnext official\smarty\.venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:345, in WebDriver.execute(self, driver_command, params)
#     342     elif "sessionId" not in params:
#     343         params["sessionId"] = self.session_id
# --> 345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
#     347     self.error_handler.check_response(response)
#
# File c:\Users\maanu\setnext official\smarty\.venv\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:302, in RemoteConnection.execute(self, command, params)
#     300 trimmed = self._trim_large_entries(params)
#     301 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 302 return self._request(command_info[0], url, body=data)
#
# File c:\Users\maanu\setnext official\smarty\.venv\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:322, in RemoteConnection._request(self, method, url, body)
#     319     body = None
#     321 if self.keep_alive:
# --> 322     response = self._conn.request(method, url, body=body, headers=headers)
#     323     statuscode = response.status
#     324 else:
#
# File c:\Users\maanu\setnext official\smarty\.venv\Lib\site-packages\urllib3\_request_methods.py:144, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     136     return self.request_encode_url(
#     137         method,
#     138         url,
#    (...)
#     141         **urlopen_kw,
#     142     )
#     143 else:
# --> 144     return self.request_encode_body(
#     145         method, url, fields=fields, headers=headers, **urlopen_kw
#     146     )
#
# File c:\Users\maanu\setnext official\smarty\.venv\Lib\site-packages\urllib3\_request_methods.py:279, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     275     extra_kw["headers"].setdefault("Content-Type", content_type)
#     277 extra_kw.update(urlopen_kw)
# --> 279 return self.urlopen(method, url, **extra_kw)
#
# File c:\Users\maanu\setnext official\smarty\.venv\Lib\site-packages\urllib3\poolmanager.py:444, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     442     response = conn.urlopen(method, url, **kw)
#     443 else:
# --> 444     response = conn.urlopen(method, u.request_uri, **kw)
#     446 redirect_location = redirect and response.get_redirect_location()
#     447 if not redirect_location:
#
# File c:\Users\maanu\setnext official\smarty\.venv\Lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File c:\Users\maanu\setnext official\smarty\.venv\Lib\site-packages\urllib3\connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\maanu\setnext official\smarty\.venv\Lib\site-packages\urllib3\connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File ~\Anaconda3\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~\Anaconda3\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\Anaconda3\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\Anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
print(id)
print(len(id))
print(name)
print(len(name))
print(rating)
print(len(rating))
print(price)
print(len(price))
print(desc)
print(len(desc))
print(image)
print(len(image))
print(product_gift)
print(len(product_gift))
# Out:
# ['32770', '12212', '21807', '33492', '19716', '23850', '21636', '33636', '35755', '28199', '14850', '35776', '35876', '34437', '34030', '31870', '29564', '23986', '30864', '26409', '33066', '32073', '33432', '33067', '30422', '33553', '29865', '29332', '24691', '33063', '28126', '28125', '34033', '19903', '33060', '27345', '33064', '35702', '19805', '30470', '33431', '24690', '25903', '29558', '33429', '35720', '27952', '32071', '19692', '24616', '24759', '19065', '33558', '35261', '34028', '11052', '29863', '35578', '30473', '33433', '35582', '35579', '10820', '34400', '22934', '34034', '13098', '423828', '35141', '11318', '34572', '32381', '13090', '24761', '35747', '36050', '35570', '31290', '22026', '19067', '33364', '25924', '12073', '30800', '35581', '35640', '35745', '24564', '33425', '17554', '16108', '16102', '35571', '34410', '35264', '35271', '26009', '28516', '35401', '34001', '22323', '33590', '31738', '34395', '34396', '26761', '34019', '32352', '36211', '14208', '33416', '32132', '34573', '35642', '35139', '35347', '35750', '33332', '24656', '30215', '35497', '35844', '35641', '21609', '35777', '35759', '27949', '35954', '35368', '22713', '35142', '11278', '30866', '35843', '30933', '35265', '33637', '33363', '33556', '35135', '34766', '19898', '12095', '425251', '33586', '36485', '35567', '35294', '35140', '15988', '36484', '15418', '36486', '35748', '15916', '29860', '35680', '26087', '35568', '32382', '31308', '34985', '35184', '35703', '34398', '513162', '35681', '29504', '34986', '35721', '34648']
# 171
# ['One K Defender CCS MIPS Helmet', 'Roeckl Roeck-Grip Gloves', 'One K Defender Matte Helmet', 'Ada Thinsulate™ Winter Barn Boot', 'Charles Owen AYR8 Plus Leather Look Helmet', 'Charles Owen AYR8 Plus Helmet', 'The Tailored Sportsman Ice Fil Long Sleeve', 'Charles Owen Halo MIPS Helmet', 'Ada Thinsulate Winter Fleece Lined Chelsea Boot by SmartPak', 'Trauma Void EQ3 Smooth Shell Helmet', 'Tipperary Sportage Helmet', "Piper Trainer's Coat II by SmartPak", 'EQx Kylo Mips Helmet by Charles Owen', 'Trauma Void Pardus Smooth Shell Helmet', 'Hadley Curvy Fit Grip Breeches by SmartPak- Knee Patch', 'The Tailored Sportsman Mid-Rise Hunter/Jumper Boot Sock Breech', 'The Tailored Sportsman Vintage Tan Patch Mid Rise Breech', 'Piper Long Sleeve Show Shirt by SmartPak', 'Charles Owen MyPS Helmet', 'Piper Softshell Show Coat II by SmartPak', 'Hadley High-Rise Breeches by SmartPak - Full Seat', 'Tipperary Windsor Rose Gold Wide Brim MIPS Helmet', 'Piper Mid-Weight Tights by SmartPak - Full Seat', 'Hadley High-Rise Breeches by SmartPak - Knee Patch', 'Trauma Void Lynx Smooth Helmet', 'Ariat Heritage Contour II H2O Insulated', 'One K Avance Wide Brim Chrome Stripe Helmet', 'Piper SmartCore™ Long Sleeve ¼ Zip Sun Shirt', 'Hadley Mid-Rise Breeches by SmartPak - Knee Patch', 'Piper Evolution Breeches by SmartPak - Knee Patch', 'Ada Tall Lace Up Boot by SmartPak', 'Ada Chelsea Boot by SmartPak', 'Piper Stretch Denim Breeches by SmartPak- Full Seat', 'Samshield Shadowmatt Helmet', 'Piper Mesh Show Coat by SmartPak', 'Ariat Langdale H20 Boot', 'Piper Evolution Breeches by SmartPak - Full Seat', 'Hadley Winter Tech Softshell Breeches by SmartPak - Full Seat', 'Heritage Premier Show Gloves', 'Ada Tall Country Leather Boot by SmartPak', 'Piper Evolution High-Rise Breeches by SmartPak - Knee Patch', 'Hadley Mid-Rise Breeches by SmartPak - Full Seat', 'Hadley SunShield Long Sleeve 1/4 Zip by SmartPak', 'Trauma Void EQ3 Microfiber Helmet', 'Piper Evolution High-Rise Breeches by SmartPak - Full Seat', 'Effax Total Leather Care Bundle', 'Dublin Eskimo Winter Boot II', 'Tipperary Windsor Wide Brim MIPS Helmet', 'The Optimum Time Eventing Watch', 'Samshield Miss Shield Helmet', 'Ariat Coniston Pro GTX Insulated', 'SmartPak Boot Bag', "Ariat Women's Ignite Waterproof", 'Kerrits Softshell Riding Vest', 'Hadley Curvy Fit Grip Breeches by SmartPak- Full Seat', 'Leather New Liquid Glycerin Saddle Soap', 'One K Defender Rose Gold Helmet', 'Piper Evolution Curvy Fit Breeches by SmartPak - Full Seat', 'Ada Mid Country Leather Boot by SmartPak', 'Piper Mid-Weight Tights by SmartPak - Knee Patch', 'Romfh Willow Knee Patch Breech', 'Piper Evolution Curvy Fit Breeches by SmartPak - Knee Patch', 'SSG All Weather Gloves', 'SmartTherapy® ThermoBalance® Ceramic Knee Patch Breech', 'RJ Classics Gulf Knee Patch Breech', 'Piper Stretch Denim Breeches by SmartPak- Knee Patch', 'SmartPak Custom Bridle Bag', 'C4 Classic Belt & Buckle', 'Piper Classic II Low-Rise Side Zip Breeches by SmartPak - Knee Patch', 'SSG The Rancher', 'Ariat Ideal Down Jacket', 'Piper Fusion Breech by SmartPak - Full Seat', 'SmartPak Custom Helmet Bag', 'Ariat Wexford H2O Chelsea Boots', 'Piper SmartCore™ Long Sleeve ¼ Zip Sun Shirt - Limited Edition', 'Epona Bestselling Brush Bundle', 'SmartTherapy®Thermobalance® Softshell Jacket', 'Piper SmartCore™ Long Sleeve Crew Neck
$27.95', '$109.95', '$185.00', '$92.95', '$61.95', '$36.00 - $44.00', '$55.77', '$50.95', '$139.95', '$113.95', '$56.95', '$189.95', '$32.86', '$31.40', '$129.95', '$41.95', '$77.99', '$36.95', '$46.95', '$14.95', '$43.95', '$54.95', '$154.95', '$49.95', '$51.06', '$99.95', '$21.95', '$42.95', '$9.95 - $10.95', '$20.95 - $23.95', '$94.95', '$30.98', '$119.00', '$119.00', '$149.99', '$15.95', '$79.95', '$61.95', '$108.95', '$303.95', '$23.95', '$58.95', '$48.95', '$64.95 - $74.95', '$102.95', '$113.95', '$9.99', '$11.00', '$189.95', '$119.00', '$109.95', '$30.95', '$46.48', '$69.50', '$20.76', '$99.00', '$149.00', '$54.95', '$148.00', '$62.30 - $69.30', '$30.95', '$39.95', '$91.16', '$37.17', '$139.95', '$45.49', '$45.00', '$13.95 - $39.95', '$61.77', '$52.95', '$249.00', '$51.80', '$169.99 - $229.99', '$139.00', '$299.00', '$51.95', '$189.95', '$84.96', '$25.90', '$690.00', '$49.95', '$42.00', '$175.95', '$61.77', '$102.95', '$37.17', '$46.48', '$69.95', '$36.48', '$229.00', '$68.37', '$23.48', '$51.95 - $61.95', '$304.95', '$90.00', '$419.00', '$92.95', '$102.95', '$48.96', '$119.95', '$29.95', '$86.76', '$119.95', '$19.95', '$120.00', '$678.00', '$109.95', '$44.51', '$139.99']
# 171
# ['OverviewWhy We Love This The ever popular One K Defender now with MIPS technology.\xa0 Founded in 1996 by a neurosurgeon and a researcher from the Royal Institute of Technology in Sweden, MIPS stands for Multi-directional Impact Protection System and is designed to add protection against rotational motion transmitted to the brain from angled impacts to the head.\xa0 MIPS added protection has been independently proven to reduce rotational motion by redirecting forces that would otherwise be transmitted to the brain. One K MIPS helmet features black matte Polycarbonate and Advanced ABS Composite outer shell; injection molded shell design; washable quick-dry, moisture wicking, anti-microbial liner;\xa0 and comfort padded harness with synthetic suede lining, hook & loop adjustment, and Fastex buckle; two front, one back, and two center stripe vents. For best care, wipe down with a clean, damp cloth for dust or dirt;machine wash removable inner liner. Compatible with the CCS Custom Color System.Personalize your helmet with the CCS system by One K! With the custom color system (css), you can choose your One K CCS Front Shield,\xa0One K CCS Top Panel\xa0and\xa0One K CCS Vent Stripe Rail. Change one piece, two pieces or all three to suit your style! \xa0ImportedCAUTION: Safety equipment must fit properly and be appropriately secured with manufacture approved parts only. Altering or adding to safety equipment voids warranty and can result in injury. As a safety precaution, inspect all products prior to each use.For additional information on fit, watch our video on how to fit your helmet. Click Here!Check out the other items we offer from One K helmets\xa0Here!One K Defender now with MIPS technology Founded in 1996 by a neurosurgeon and a researcher from the Royal Institute of Technology in Sweden MIPS stands for Multi-directional Impact Protection System and is designed to add protection against rotational motion transmitted to the brain from angled impacts to the head MIPS added protection has been independently proven to reduce rotational motion by redirecting forces that would otherwise be transmitted to the brain.  One K MIPS helmet features black matte Polycarbonate and Advanced ABS Composite outer shell Injection molded shell design Washable quick-dry, moisture wicking, anti-microbial liner Comfort padded harness with synthetic suede lining, hook & loop adjustment, and Fastex buckle
man-midrise-hunterjumper-boot-sock-breech--21870', 'https://www.smartpakequine.com//pt/the-tailored-sportsman-vintage-tan-patch-mid-rise-breech-19564', 'https://www.smartpakequine.com//pt/piper-long-sleeve-show-shirt-by-smartpak-13986', 'https://www.smartpakequine.com//pt/charles-owen-myps-helmet-20864', 'https://www.smartpakequine.com//pt/piper-softshell-show-coat-ii-by-smartpak-16409', 'https://www.smartpakequine.com//pt/hadley-highrise-breeches-by-smartpak--full-seat-23066', 'https://www.smartpakequine.com//pt/tipperary-windsor-rose-gold-wide-brim-mips-helmet-22073', 'https://www.smartpakequine.com//pt/piper-midweight-tights-by-smartpak--full-seat-23432', 'https://www.smartpakequine.com//pt/hadley-highrise-breeches-by-smartpak--knee-patch-23067', 'https://www.smartpakequine.com//pt/trauma-void-lynx-smooth-helmet-20422', 'https://www.smartpakequine.com//pt/ariat-heritage-contour-ii-h2o-insulated-23553', 'https://www.smartpakequine.com//pt/one-k-avance-wide-brim-chrome-stripe-helmet-19865', 'https://www.smartpakequine.com//pt/piper-smartcore-long-sleeve--zip-sun-shirt-19332', 'https://www.smartpakequine.com//pt/hadley-midrise-breeches-by-smartpak--knee-patch-14691', 'https://www.smartpakequine.com//pt/piper-evolution-breeches-by-smartpak--knee-patch-23063', 'https://www.smartpakequine.com//pt/ada-tall-lace-up-boot-by-smartpak-18126', 'https://www.smartpakequine.com//pt/ada-chelsea-boot-by-smartpak-18125', 'https://www.smartpakequine.com//pt/piper-stretch-denim-breeches-by-smartpak-full-seat-24033', 'https://www.smartpakequine.com//pt/samshield-shadowmatt-helmet-9903', 'https://www.smartpakequine.com//pt/piper-mesh-show-coat-by-smartpak-23060', 'https://www.smartpakequine.com//pt/ariat-langdale-h20-boot-17345', 'https://www.smartpakequine.com//pt/piper-evolution-breeches-by-smartpak--full-seat-23064', 'https://www.smartpakequine.com//pt/hadley-winter-tech-softshell-breeches-by-smartpak--full-seat-25702', 'https://www.smartpakequine.com//pt/heritage-premier-show-gloves-9805', 'https://www.smartpakequine.com//pt/ada-tall-country-leather-boot-by-smartpak-20470', 'https://www.smartpakequine.com//pt/piper-evolution-highrise-breeches-by-smartpak--knee-patch-23431', 'https://www.smartpakequine.com//pt/hadley-midrise-breeches-by-smartpak--full-seat-14690', 'https://www.smartpakequine.com//pt/hadley-sunshield-long-sleeve-14-zip-by-smartpak--15903', 'https://www.smartpakequine.com//pt/trauma-void-eq3-microfiber-helmet-19558', 'https://www.smartpakequine.com//pt/piper-evolution-highrise-breeches-by-smartpak--full-seat-23429', 'https://www.smartpakequine.com//pt/effax-total-leather-care-bundle-25720', 'https://www.smartpakequine.com//pt/dublin-eskimo-winter-boot-ii-17952', 'https://www.smartpakequine. ...
# 595

# %%
# df_product_gifts = pd.DataFrame(list(zip(id,name,rating,price,desc,image,product_gift)),columns=['Id','Product Name','Rating','Price','Description','Image_URL','Product_link'])
# df_product_gifts.to_excel("products_gifts.xlsx", index = False)

df_product_gifts = pd.DataFrame(list(zip(id,name,rating,price,desc,image,gift_for_dogs_links,brand)),columns=['Id','Product Name','Rating','Price','Description','Image_URL','Product_link','Brand'])
df_product_gifts.to_csv("gift_for_dogs.csv", index = False)

# %%
import pandas as pd
# Out:
# C:\Users\maanu\AppData\Local\Temp\ipykernel_4520\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv("C:/Users/maanu/Downloads/gift.csv")
df.head(5)
# Out:
#       Id                                      Product Name  Rating  \
# 0  17901                             Mrs. Pasture® Cookies     4.9
# 1  32509  The German Horse Muffin All Natural Horse Treats     4.9
# 2  24038                                      SmartCookies     4.5
# 3  14867                       Uncle Jimmy's Hangin' Balls     4.3
# 4  32530                                   Hay Ball Feeder     4.3
#
#              Price                                        Description  \
# 0  $14.20 - $72.95  OverviewWhy We Love This Mrs Pastures Horse Co...
# 1   $8.50 - $78.95  OverviewWhy We Love This Each muffin is a deca...
# 2  $13.25 - $39.95  OverviewWhy We Love This Treat your horse righ...
# 3  $22.75 - $23.95  OverviewWhy We Love This Uncle Jimmy recorded ...
# 4           $86.00  OverviewWhy We Love This Made in the USA the H...
#
#                                            Image_URL  \
# 0  https://img.smartpak.com/images/product/highre...
# 1  https://img.smartpak.com/images/product/highre...
# 2  https://img.smartpak.com/images/product/highre...
# 3  https://img.smartpak.com/images/product/highre...
# 4  https://img.smartpak.com/images/product/highre...
#
#                                         Product_link  \
# 0  https://www.smartpakequine.com//pt/mrs-pasture...
# 1  https://www.smartpakequine.com//pt/the-german-...
# 2  https://www.smartpakequine.com//pt/smartcookie...
# 3  https://www.smartpakequine.com//pt/uncle-jimmy...
# 4  https://www.smartpakequine.com//pt/hay-ball-fe...
#
#                               Brand                   subcategory category
# 0  Mrs. Pastures Cookies for Horses  Treats Toys For Horses Gifts     GIFT
# 1                               NaN  Treats Toys For Horses Gifts     GIFT
# 2                   SmartPak Equine  Treats Toys For Horses Gifts     GIFT
# 3       Uncle Jimmy's Hangin' Balls  Treats Toys For Horses Gifts     GIFT
# 4                 Burlingham Sports  Treats Toys For Horses Gifts     GIFT

# %%
df.subcategory.values
# Out:
# array(['Treats Toys For Horses Gifts', 'Treats Toys For Horses Gifts',
#        'Treats Toys For Horses Gifts', 'Treats Toys For Horses Gifts',
#        'Treats Toys For Horses Gifts', 'Treats Toys For Horses Gifts',
#        'Treats Toys For Horses Gifts', 'Treats Toys For Horses Gifts',
#        'Treats Toys For Horses Gifts', 'Treats Toys For Horses Gifts',
#        'Treats Toys For Horses Gifts', 'Treats Toys For Horses Gifts',
#        'Treats Toys For Horses Gifts', 'Treats Toys For Horses Gifts',
#        'Treats Toys For Horses Gifts', 'Treats Toys For Horses Gifts',
#        'Treats Toys For Horses Gifts', 'Treats Toys For Horses Gifts',
#        'Treats Toys For Horses Gifts', 'Treats Toys For Horses Gifts',
#        'Treats Toys For Horses Gifts', 'Treats Toys For Horses Gifts',
#        'Treats Toys For Horses Gifts', 'Treats Toys For Horses Gifts',
#        'Treats Toys For Horses Gifts', 'Gift For Dogs', 'Gift For Dogs',
#        'Gift For Dogs', 'Gift For Dogs', 'Gift For Dogs', 'Gift For Dogs',
#        'Gift For Dogs', 'Gift For Dogs', 'Gift For Dogs', 'Gift For Dogs',
