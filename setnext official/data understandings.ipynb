# %%
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
df=pd.read_csv('Product_and_class_data.csv')
df.head()
# Out:
# C:\Users\maanu\AppData\Local\Temp\ipykernel_23792\150835939.py:1: DtypeWarning: Columns (4,10,11,21,32,38,42,48,59,62,68,69,70,71,72,73,77,79,81,82,84,85,87,88,89,92,93,99,100,101,102,124,150,167,175) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('Product_and_class_data.csv')
#    ProductClassID                    ProductClassName       MfgID  \
# 0               7                        Wipe&reg; II  1898764483
# 1              17                     Quiessence&reg;   960579234
# 2              17                     Quiessence&reg;   960579234
# 3              17                     Quiessence&reg;   960579234
# 4              18  Corona&reg; Multi-Purpose Ointment   958578865
#
#                                            ShortDesc  \
# 0  Wipe&reg; II Fly Spray with Citronella has bee...
# 1  Quiessence&reg; provides high levels of Magnes...
# 2  Quiessence&reg; provides high levels of Magnes...
# ...

# %%
# print(df.columns)
for a in df.columns:
    print(a)
# Out:
# ProductClassID
# ProductClassName
# MfgID
# ShortDesc
# Details
# Inactive
# Created
# Ingredients
# DetailsInsert
# DetailsCat
# Accolades
# Precautions
# Keywords
# IsSale
# PartNumber
# WebPhoto
# ShowNote
# CategorySortOrder
# ProductID
# Orderable
# SaleText
# CustomText
# IsConsumable
# ReportingCategoryID
# Deleted
# Modified
# AnimalTypeID
# Headline
# SupplementLabelImage
# ProductClassType
# SmartPakDosingDisclaimer
# Catalog
# SizingDescription
# SizingChart
# SizingChartPopup
# NASCSeal
# PrimaryCategory
# CustomizationIsRequired
# SampleCustomizationHtml
# excludeFromSearch
# ActiveDate
# BannerAdPath
# CatalogCopy
# CountryId
# IsPickyEaterApproved
# IsPrivateLabel
# IsLeadingBrand
# ExcludeFromPromos
# ShortProductDesc
# SpecialOfferMessage
# RowVersionStamp
# IsShowBucketPrices
# ItemNumber
# TitleTag
# OrderableModifiedDate
# SmartSupplyPackageTypeId
# BuyerId
# SchedulerId
# ProductClassShortName
# DescriptionTag
# ProductLabel
# Research
# DosageInfo
# ...
